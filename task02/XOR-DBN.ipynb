# %%
import sys
if '../' not in sys.path:
    sys.path.append('../')
if '../task01' not in sys.path:
    sys.path.append('../task01')

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

from data import data_problems_examples
import RBM as rbm
import DBN as dbn
import neural_network as backprop

# %matplotlib inline

# %%
def indicator_estimator(predicted, observed):
    return 100.0 * np.sum(predicted == observed) / observed.shape[0]

# %%
type_chosen = 'xor'

X_train, Y_train = data_problems_examples.generate_problem(n_size=50, type=type_chosen)
X_test, Y_test = data_problems_examples.generate_problem(n_size=50, type=type_chosen)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X_train[:, 0], X_train[:, 1], c=Y_train, s=30)
plt.grid()

# %%
nn_rbm = dbn.DBN(layers=[
        rbm.BernoulliLayer(X_train.shape[1]),
        rbm.BernoulliLayer(2 * X_train.shape[1]),
        rbm.BernoulliLayer(4 * X_train.shape[1]),
        rbm.BernoulliLayer(8 * X_train.shape[1])
    ], loss_function='NLL')

nn_rbm.fit(np.round(X_train), n_epochs=100, learning_rate=.01, n_gibbs_steps=1, batch_size=10)
# Out:
# epoch = 99; learning_rate = 0.01; criteria_train = 1.38340076914;
# epoch = 99; learning_rate = 0.01; criteria_train = 2.76343072137;
# epoch = 99; learning_rate = 0.01; criteria_train = 5.47904800471;
